# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8


version = '1.18.2' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit)

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version
if server_type == 'fabric':
    serverURL = 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/0.11.2/fabric-installer-0.11.2.jar'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version

jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading



#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]

if colabconfig["server_version"] < "1.17":

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-8-jre-headless &>/dev/null and print("OpenJDK 8 instalado!") or print("Error al intalar OpenJDK 8.")

else:

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")


# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

if java_ver[0] == "17":

    print("Estas usando JAVA 17.")

else:

    print("Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.")



#Lista de posibles archivos .jar


jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar"}

jar_name = jar_list[colabconfig["server_type"]]



# Java arguments.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2d1UBOFbE8tGNdJXqfTZQG0aNPn_3HzFouwi9fHH4GVFLzoe5" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))



print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)
# Out:
# el apt cache fue actualizado correctamente
# Land_Towers	     defaultconfigs  mohist-config	 scripts
# Ocean_Towers	     eula.txt	     mohist.jar		 server.properties
# banned-ips.json      forge.jar	     ops.json		 simplebackups
# banned-players.json  forge.jar.log   patchouli_books	 spigot.yml
# bukkit.yml	     global_packs    permissions.yml	 user_jvm_args.txt
# colabconfig.json     help.yml	     pfmUpdateInfo.json  usercache.json
# commands.yml	     libraries	     plugins		 usernamecache.json
# config		     logs	     resourcepacks	 whitelist.json
# crash-reports	     modernfix	     run.bat		 world
# datapacks	     mods	     run.sh
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")'
# Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:18139
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.18.2-146, Java(21.0.2) 65.0
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# No update found, the latest version: (146) current version: (146)
# Checking libraries, please wait...
# DownloadSource: MOHIST
# Download percentage:
#    0% [                                                    ] 0/1 (0:00:00 / ?)
# All libraries are nice :)!===========================] 1/1 (0:00:00 / 0:00:00)
# [03:57:07 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 40.2.17, --fml.mcVersion, 1.18.2, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20220404.173914, nogui]
# [03:57:07 INFO]: ModLauncher 9.1.3+9.1.3+main.9b69c82a starting: java version 21.0.2 by Microsoft
# [03:57:07 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2316!/ Service=ModLauncher Env=SERVER
# [03:57:08 INFO]: Found 3 dependencies adding them to mods collection
# [03:57:09 WARN]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [03:57:09 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: mixinextras. Using Mod File:
# [03:57:09 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: flywheel. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/flywheel-forge-1.18.2-0.6.8.a.jar
# [03:57:09 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: MixinExtras-0.2.0.jar. Using Mod File:
# [03:57:09 INFO]: Found 1 dependencies adding them to mods collection
# [03:57:09 WARN]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [03:57:09 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: mixinextras. Using Mod File:
# [03:57:09 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: flywheel. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/flywheel-forge-1.18.2-0.6.8.a.jar
# [03:57:09 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: Registrate-MC1.18.2-1.1.3.jar. Using Mod File:
# [03:57:09 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: MixinExtras-0.2.0.jar. Using Mod File:
# [03:57:09 INFO]: No dependencies to load found. Skipping!
# Init ItemPhysic coremods ...
# [03:57:16 INFO]: Compatibility level set to JAVA_17
# [03:57:16 ERROR]: Mixin config pmmo.mixins.json does not specify "minVersion" property
# [03:57:16 ERROR]: Mixin config rei-jei-internals-workaround.mixins.json does not specify "minVersion" property
# [03:57:16 ERROR]: Mixin config itshallnottick.mixins.json does not specify "minVersion" property
# [03:57:16 ERROR]: Mixin config polylib.mixins.json does not specify "minVersion" property
# [03:57:17 ERROR]: Mixin config rei.mixins.json does not specify "minVersion" property
# [03:57:17 INFO]: Successfully loaded Mixin Connector [com.sonicether.soundphysics.MixinConnector]
# [03:57:17 INFO]: Successfully loaded Mixin Connector [tictim.paraglider.MixinConnector]
# [03:57:17 INFO]: Successfully loaded Mixin Connector [ca.spottedleaf.starlight.mixin.MixinConnector]
# [03:57:17 INFO]: Successfully loaded Mixin Connector [net.cravencraft.epicparagliders.MixinConnector]
# [03:57:17 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [03:57:17 INFO]: Loaded configuration file for ModernFix 5.8.1+mc1.18.2: 69 options available, 0 override(s) found
# [03:57:17 INFO]: Applying Nashorn fix
# [03:57:17 INFO]: Applied Forge config corruption patch
# [03:57:17 WARN]: Reference map 'wildbackport-forge-refmap.json' for wildbackport.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 WARN]: Reference map 'yungsbridges.refmap.json' for yungsbridges.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 WARN]: Reference map 'yungsbridges.refmap.json' for yungsbridges_forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 WARN]: Reference map 'yungsextras.refmap.json' for yungsextras.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 WARN]: Reference map 'yungsextras.refmap.json' for yungsextras_forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 WARN]: Reference map 'untamedwilds.refmap.json' for untamedwilds.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 WARN]: Reference map 'thirst.refmap.json' for villagercomfort.mixin.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 WARN]: Reference map 'idas.refmap.json' for idas.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 WARN]: Reference map 'antiqueatlas-forge-refmap.json' for antiqueatlas.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 WARN]: Reference map 'insanelib.refmap.json' for insanelib.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 WARN]: Reference map 'piglinproliferation.refmap.json' for piglinproliferation.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 INFO]: Please use /mfsrc to reload any changed mod config files
# [03:57:17 WARN]: Reference map 'polylib-common-refmap.json' for polylib.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 WARN]: Reference map 'creativecore.mixins.refmap.json' for creativecore.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:57:17 WARN]: Reference map 'nethersdelight.refmap.json' for nethersdelight.mixins.json could not be read. If this is a development environment you can ignore this message
# [Serene Seasons Transformer]: Transforming m_47480_ (Lnet/minecraft/world/level/LevelReader;Lnet/minecraft/core/BlockPos;Z)Z in net/minecraft/world/level/biome/Biome
# [Serene Seasons Transformer]: Patched 1 calls
# [Serene Seasons Transformer]: Transforming m_47519_ (Lnet/minecraft/world/level/LevelReader;Lnet/minecraft/core/BlockPos;)Z in net/minecraft/world/level/biome/Biome
# [Serene Seasons Transformer]: Successfully patched shouldSnow
# [03:57:18 WARN]: Error loading class: net/minecraft/client/model/IronGolemModel (java.lang.ClassNotFoundException: net.minecraft.client.model.IronGolemModel)
# [03:57:18 WARN]: @Mixin target net.minecraft.client.model.IronGolemModel was not found strawgolem.mixins.json:IronGolemModelMixin
# [Serene Seasons Transformer]: Transforming m_8714_ (Lnet/minecraft/world/level/chunk/LevelChunk;I)V in net/minecraft/server/level/ServerLevel
# [Serene Seasons Transformer]: Successfully patched tickChunk
# [03:57:18 FATAL]: Attempted to load class net/minecraft/client/Minecraft for invalid dist DEDICATED_SERVER
# [03:57:18 WARN]: Error loading class: net/minecraft/client/Minecraft (java.lang.RuntimeException: Attempted to load class net/minecraft/client/Minecraft for invalid dist DEDICATED_SERVER)
# [03:57:18 WARN]: @Mixin target net.minecraft.client.Minecraft was not found modernfix-common.mixins.json:bugfix.world_leaks.MinecraftMixin
# [03:57:18 FATAL]: Attempted to load class com/mojang/blaze3d/vertex/BufferBuilder for invalid dist DEDICATED_SERVER
# [03:57:18 WARN]: Error loading class: com/mojang/blaze3d/vertex/BufferBuilder (java.lang.RuntimeException: Attempted to load class com/mojang/blaze3d/vertex/BufferBuilder for invalid dist DEDICATED_SERVER)
# [03:57:18 WARN]: @Mixin target com.mojang.blaze3d.vertex.BufferBuilder was not found modernfix-common.mixins.json:bugfix.buffer_builder_leak.BufferBuilderMixin
# [03:57:19 WARN]: Error loading class: net/minecraft/client/model/geom/ModelPart (java.lang.ClassNotFoundException: net.minecraft.client.model.geom.ModelPart)
# [03:57:19 WARN]: @Mixin target net.minecraft.client.model.geom.ModelPart was not found wildbackport-common.mixins.json:access.ModelPartAccessor
# [03:57:19 FATAL]: Attempted to load class net/minecraft/client/renderer/RenderType for invalid dist DEDICATED_SERVER
# [03:57:19 WARN]: Error loading class: net/minecraft/client/renderer/RenderType (java.lang.RuntimeException: Attempted to load class net/minecraft/client/renderer/RenderType for invalid dist DEDICATED_SERVER)
# [03:57:19 WARN]: @Mixin target net.minecraft.client.renderer.RenderType was not found wildbackport-common.mixins.json:access.RenderTypeAccessor
# [03:57:19 FATAL]: Attempted to load class net/minecraft/client/renderer/Sheets for invalid dist DEDICATED_SERVER
# [03:57:19 WARN]: Error loading class: net/minecraft/client/renderer/Sheets (java.lang.RuntimeException: Attempted to load class net/minecraft/client/renderer/Sheets for invalid dist DEDICATED_SERVER)
# [03:57:19 WARN]: @Mixin target net.minecraft.client.renderer.Sheets was not found wildbackport-common.mixins.json:access.SheetsAccessor
# [03:57:19 WARN]: Error loading class: net/silentchaos512/gear/item/gear/GearCrossbowItem (java.lang.ClassNotFoundException: net.silentchaos512.gear.item.gear.GearCrossbowItem)
# [03:57:19 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/inventory/AnvilMenu
# [03:57:19 INFO]: find block call
# [03:57:20 INFO]: Patching FishingHook#catchingFish
# [03:57:20 WARN]: Error loading class: mezz/jei/common/transfer/RecipeTransferUtil (java.lang.ClassNotFoundException: mezz.jei.common.transfer.RecipeTransferUtil)
# [03:57:20 WARN]: @Mixin target mezz.jei.common.transfer.RecipeTransferUtil was not found polymorph_integrations.mixins.json:jei.MixinRecipeTransferUtil
# [03:57:20 INFO]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [03:57:20 INFO]: Replaced 1 calls to Enchantment#isTreasureOnly() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [03:57:20 INFO]: Replaced 1 calls to Enchantment#isTradeable() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [03:57:20 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/item/EnchantedBookItem
# [03:57:20 INFO]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [03:57:20 INFO]: Replaced 1 calls to Enchantment#isDiscoverable() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [03:57:20 INFO]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.2.0).
# [03:57:21 INFO]: ModernFix reached bootstrap stage (19.35 s after launch)
# [03:57:21 INFO]: Injecting BlockStateBase cache population hook into getOpacityIfCached from ca.spottedleaf.starlight.mixin.common.blockstate.BlockStateBaseMixin
# [03:57:21 INFO]: Injecting BlockStateBase cache population hook into isConditionallyFullOpaque from ca.spottedleaf.starlight.mixin.common.blockstate.BlockStateBaseMixin
# t=2024-02-29T03:57:22+0000 lvl=warn msg="failed to open private leg" id=94d58ea87363 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [Serene Seasons Transformer]: Transforming m_8714_ (Lnet/minecraft/world/level/chunk/LevelChunk;I)V in net/minecraft/server/level/ServerLevel
# [Serene Seasons Transformer]: Successfully patched tickChunk
# t=2024-02-29T03:57:22+0000 lvl=warn msg="failed to open private leg" id=3005c9d53ff9 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [03:57:22 INFO]: find block call
# [Serene Seasons Transformer]: Transforming m_47480_ (Lnet/minecraft/world/level/LevelReader;Lnet/minecraft/core/BlockPos;Z)Z in net/minecraft/world/level/biome/Biome
# [Serene Seasons Transformer]: Patched 1 calls
# [Serene Seasons Transformer]: Transforming m_47519_ (Lnet/minecraft/world/level/LevelReader;Lnet/minecraft/core/BlockPos;)Z in net/minecraft/world/level/biome/Biome
# [Serene Seasons Transformer]: Successfully patched shouldSnow
# [03:57:22 WARN]: Static binding violation: PRIVATE @Overwrite method m_47505_ in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin cannot reduce visibiliy of PUBLIC target method, visibility will be upgraded.
# [03:57:22 WARN]: Method overwrite conflict for m_47505_ in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin, previously written by com.abdelaziz.saturn.mixin.world.temperature_cache.BiomeMixin. Skipping method.
# [03:57:24 INFO]: Vanilla bootstrap took 2987 milliseconds
# [Serene Seasons Transformer]: Transforming m_8107_ ()V in net/minecraft/world/entity/animal/SnowGolem
# [Serene Seasons Transformer]: Patched 1 calls
# [03:57:24 INFO]: Replaced 5 calls to Enchantment#getMaxLevel() in vazkii/quark/content/tools/module/AncientTomesModule
# [03:57:25 WARN]: @Final field f_31427_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [03:57:25 WARN]: @Final field f_31428_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [03:57:25 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/inventory/AnvilMenu
# [03:57:25 INFO]: Replaced 1 calls to Enchantment#getMaxLevel() in com/mrcrayfish/goblintraders/Hooks
# [03:57:27 INFO]: Patching FishingHook#catchingFish
# [03:57:27 WARN]: @Redirect conflict. Skipping immersive_weathering-common.mixins.json:LevelChunkMixin->@Redirect::warn(Lorg/slf4j/Logger;Ljava/lang/String;Ljava/lang/Object;Ljava/lang/Object;)V with priority 1000, already redirected by supplementaries.mixins.json:LevelChunkMixin->@Redirect::warn(Lorg/slf4j/Logger;Ljava/lang/String;Ljava/lang/Object;Ljava/lang/Object;)V with priority 1000
# [03:57:27 WARN]: @ModifyConstant conflict. Skipping integrated_api.mixins.json:structures.StructurePoolMixin->@ModifyConstant::integrated_api_increaseWeightLimitDev(I)I with priority 1000, already redirected by yungsapi.mixins.json:IncreaseStructureWeightLimitMixin->@ModifyConstant::yungsapi_increaseWeightLimit(I)I with priority 1000
# [03:57:28 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/item/EnchantedBookItem
# [03:57:28 INFO]: Potentially Dangerous alternative prefix `cloudstorage` for name `balloon_hurt`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:57:28 INFO]: Potentially Dangerous alternative prefix `cloudstorage` for name `balloon_pop`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:57:28 INFO]: Potentially Dangerous alternative prefix `cloudstorage` for name `bloviator_idle`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:57:28 INFO]: Potentially Dangerous alternative prefix `cloudstorage` for name `bloviator_hurt`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:57:28 INFO]: Potentially Dangerous alternative prefix `cloudstorage` for name `bloviator_blow`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:57:28 INFO]: Potentially Dangerous alternative prefix `cloudstorage` for name `bloviator_lightning`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:57:28 INFO]: Potentially Dangerous alternative prefix `cloudstorage` for name `cloud_chest_open`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:57:28 INFO]: Potentially Dangerous alternative prefix `cloudstorage` for name `cloud_chest_close`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:57:28 INFO]: Potentially Dangerous alternative prefix `cloudstorage` for name `static_shock`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:57:28 INFO]: Potentially Dangerous alternative prefix `cloudstorage` for name `music_disc_drift`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:57:28 INFO]: Potentially Dangerous alternative prefix `cloudstorage` for name `balloon_salesman`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:57:28 INFO]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [03:57:28 INFO]: Replaced 1 calls to Enchantment#isDiscoverable() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [03:57:29 WARN]: ⚠ The log level for APTweaks(Core) is set to ALL, this will log all debug information and will cause performance issues. This is expected on an developer environment or for testing but not on a production environment!
# [03:57:29 WARN]: Adjusting log level for APTweaks(Core) from ALL to INFO, for performance reasons!
# [03:57:29 INFO]: Changing log level for APTweaks(Core) from ALL to INFO
# [03:57:29 INFO]: Register Adaptive Performance Tweaks: Core common config ...
# [03:57:29 WARN]: WARNING: Auudio is a client mod and has no effect when loaded on a server!
# [03:57:29 INFO]: Second Chance: Sound Events Registered!
# [03:57:29 INFO]: Pre-init started!
# [03:57:29 INFO]: Registering config
# [03:57:29 INFO]: Registering particles
# [03:57:29 INFO]: Registering items
# [03:57:30 INFO]: Registering entities
# [03:57:30 INFO]: Registering sounds
# [03:57:30 INFO]: Registering capabilities
# [03:57:30 INFO]: Loaded maxhealthfix for Forge.
# [03:57:30 INFO]: Better Compatibility Checker loading
# hardermonsterboats: Registering Mod.
# [03:57:30 INFO]: Constructing common components for tinyskeletons:main
# [03:57:31 INFO]: Loading config: /workspaces/codespaces-jupyter/Minecraft-server/config/illageandspillage-client.toml
# [03:57:31 INFO]: Built config: /workspaces/codespaces-jupyter/Minecraft-server/config/illageandspillage-client.toml
# [03:57:31 INFO]: Loaded config: /workspaces/codespaces-jupyter/Minecraft-server/config/illageandspillage-client.toml
# [03:57:31 INFO]: Loading config: /workspaces/codespaces-jupyter/Minecraft-server/config/illageandspillage-common.toml
# [03:57:31 INFO]: Built config: /workspaces/codespaces-jupyter/Minecraft-server/config/illageandspillage-common.toml
# [03:57:31 INFO]: Loaded config: /workspaces/codespaces-jupyter/Minecraft-server/config/illageandspillage-common.toml
# [03:57:31 INFO]: Constructing common components for mutantmonsters:main
# [03:57:31 INFO]: libraryferret - > Initialize library
# [03:57:31 INFO]: libraryferret - > Initialized library
# [03:57:31 INFO]: Forge mod loading, version 40.2.17, for MC 1.18.2 with MCP 20220404.173914
# [03:57:31 INFO]: MinecraftForge v40.2.17 Initialized
# [03:57:32 INFO]: EventDispatcherRegistry initialized
# [Mouse Tweaks] Disabled because not running on the client.
# [03:57:32 INFO]: Constructing common components for puzzleslib:main
# [03:57:33 WARN]: Attempting to add a Lambda listener with computed generic type of Event. Are you sure this is what you meant? NOTE : there are complex lambda forms where the generic type information is erased and cannot be recovered at runtime.
# [03:57:33 INFO]: Successfully loaded the Modding Legacy supporters list.
# [03:57:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [03:57:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [03:57:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [03:57:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [03:57:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [03:57:33 INFO]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [03:57:33 WARN]: @Final field f_31201_:Lorg/slf4j/Logger; in progressivebosses.mixins.json:DragonChargePlayerPhaseMixin should be final
# [03:57:33 WARN]: [Paladin's Furniture Update Check] Cached update file detected, using that!
# [03:57:33 WARN]: [Paladin's Furniture Update Check] New update detected, showing update message!
# [03:57:33 ERROR]: You are loading Let Sleeping Dogs Lie on a server. Let Sleeping Dogs Lie is a client only mod!
# [03:57:33 INFO]: Loading Collective version 6.62.
# [03:57:33 INFO]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [03:57:33 INFO]: Replaced 1 calls to Enchantment#isTreasureOnly() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [03:57:33 INFO]: Replaced 1 calls to Enchantment#isTradeable() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [03:57:33 WARN]: ⚠ The log level for APTweaks(Items) is set to ALL, this will log all debug information and will cause performance issues. This is expected on an developer environment or for testing but not on a production environment!
# [03:57:33 WARN]: Adjusting log level for APTweaks(Items) from ALL to INFO, for performance reasons!
# [03:57:33 INFO]: Changing log level for APTweaks(Items) from ALL to INFO
# [03:57:33 INFO]: Registering Adaptive Performance Tweaks: Items common config ...
# [03:57:33 INFO]: Shrines 1.18.2-4.1.0 initialized
# [03:57:34 INFO]: Detected new forge version, registering events reflectively.
# [03:57:35 INFO]: Here we go! Launching Dungeon Crawl 2.3.12...
# [03:57:35 FATAL]: Attempted to load class me/shedaniel/rei/api/client/plugins/REIClientPlugin for invalid dist DEDICATED_SERVER
# [03:57:35 FATAL]: Attempted to load class me/shedaniel/rei/api/client/plugins/REIClientPlugin for invalid dist DEDICATED_SERVER
# [03:57:36 FATAL]: Attempted to load class me/shedaniel/rei/api/client/plugins/REIClientPlugin for invalid dist DEDICATED_SERVER
# [03:57:36 FATAL]: Attempted to load class me/shedaniel/rei/api/client/plugins/REIClientPlugin for invalid dist DEDICATED_SERVER
# [03:57:36 INFO]: Replaced 5 calls to Enchantment#getMaxLevel() in vazkii/quark/content/tools/module/AncientTomesModule
# [03:57:36 INFO]: Replaced 3 calls to Enchantment#getMaxLevel() in vazkii/quark/content/tools/item/AncientTomeItem
# [03:57:37 INFO]: DawnCraft Tweaks 1.18.2-1.2.4 initialized
# [03:57:37 INFO]: Loading compatibility module with SereneSeasons
# [03:57:37 INFO]: Loading compatibility module with Patchouli
# [03:57:38 INFO]: HELLO from Register Block
# [03:57:41 WARN]: @Final field repairMaterial:Ljava/util/function/Supplier; in dawncraft-fixes.mixins.json:goblinsanddungeons.MixinGDArmorMaterial should be final
# [03:57:41 INFO]: Bypassed Mojang DFU
# [03:57:41 INFO]: Instantiating Mojang DFU
# [03:57:41 INFO]: Lazy DFU
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/habitat-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/enchantlimiter-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/betterdungeons-forge-1_18.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/adaptive_performance_tweaks/core.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/deleteitem-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/secondchanceforge-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/nyfsquiver-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/modernfix-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/armorcurve-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/guardvillagers-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/betterfortresses-forge-1_18_2.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/paraglider-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/majruszsdifficulty-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/morevillagers-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/bcc-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/timeout_fixes-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/hardermonsterboats-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/cc-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/bettermineshafts-forge-1_18.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/humancompanions-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/pmmo-common.toml
# [03:57:44 INFO]: Loading common config for mutantmonsters
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/mowziesmobs-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/goblintraders-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/passablefoliage-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/immersive_weathering-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/sereneseasons/fertility.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/sereneseasons/seasons.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/villager-comfort.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/logbegone.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/logprot-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/simplebackups-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/presencenotrequired-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/lootr-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/followme-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/Obscuria Collection/ob-core.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/Obscuria/aquamirae-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ecologics.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/blue_skies-common.toml
# [03:57:44 INFO]: Loading Config: blue_skies-common.toml
# [03:57:44 INFO]: Loading Config: blue_skies-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/treechop-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/Hexerei-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/betterwitchhuts-forge-1_18_2.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/sophisticatedcore-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/betteroceanmonuments-forge-1_18_2.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/insanelib-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/sophisticatedbackpacks-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/progressivebosses-common.toml
# [03:57:44 WARN]: Entity botania:pink_wither for Wither's Difficulty Feature entityBlacklist doesn't exist, will be ignored.
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/dummmmmmy-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/itshallnottick-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/bloodandmadness-common.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/endrem.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/projectile.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/touch.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/self.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/break.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/betterstrongholds-forge-1_18.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/harm.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/ignite.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/phantom_block.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/heal.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/grow.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/gust.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/light.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/dispel.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/launch.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/pull.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/blink.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/explosion.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/lightning.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/slowfall.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/aquatic.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/fangs.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/summon_vex.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/accelerate.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/decelerate.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/split.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/amplify.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/aoe.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/extend_time.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/pierce.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/dampen.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/extract.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/fortune.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/ender_inventory.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/harvest.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/fell.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/pickup.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/interact.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/place_block.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/snare.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/smelt.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/leap.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/delay.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/redstone_signal.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/intangible.toml
# [03:57:44 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/invisibility.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/duration_down.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/wither.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/exchange.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/craft.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/flare.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/cold_snap.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/conjure_water.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/gravity.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/cut.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/crush.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/summon_wolves.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/summon_steed.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/summon_decoy.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/hex.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/underfoot.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/glide.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/orbit.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/rune.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/freeze.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/name.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/summon_undead.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ageingspawners-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/firework.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/toss.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/aiimprovements-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/bounce.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/sensitive.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/wind_shear.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/evaporate.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/linger.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau/sense_magic.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/adaptive_performance_tweaks/items.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/limitedchunks-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ars_nouveau-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/shrines/settings.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/callablehorses-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/waystones-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/monsterplus-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/betterdeserttemples-forge-1_18_2.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/conjurer_illager-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/supplementaries-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/supplementaries-registry.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/jade-addons.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/weaponmaster-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/ba-battletowers-config.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/brutalbosses-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/hunterillager-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/dannys_expansion-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/citadel-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/alexsmobs.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/quark-common.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/cloud-storage.toml
# [03:57:45 INFO]: Loaded default config values from file at path /workspaces/codespaces-jupyter/Minecraft-server/defaultconfigs/untamedwilds-common.toml
# ...
# 	at net.minecraft.network.Connection.m_129541_(Connection.java:406) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.network.ServerConnectionListener.m_9721_(ServerConnectionListener.java:179) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.MinecraftServer.m_5703_(MinecraftServer.java:1135) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.dedicated.DedicatedServer.m_5703_(DedicatedServer.java:377) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.MinecraftServer.m_5705_(MinecraftServer.java:1049) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:874) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.MinecraftServer.m_177918_(MinecraftServer.java:287) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# Caused by: java.lang.NullPointerException: Cannot invoke "bottomtextdanny.dannys_expansion._base.capabilities.player.PlayerCapability.gunModule()" because the return value of "net.minecraftforge.common.util.LazyOptional.orElse(Object)" is null
# 	at bottomtextdanny.dannys_expansion._base.capabilities.player.PlayerHelper.gunModule(PlayerHelper.java:17) ~[dannys_expansion-1.2.6.jar%23122!/:1.2.6]
# 	at bottomtextdanny.dannys_expansion._base.gameplay_hooks.TickHooks.playerTickHook(TickHooks.java:22) ~[dannys_expansion-1.2.6.jar%23122!/:1.2.6]
# 	at net.minecraftforge.eventbus.EventBus.doCastFilter(EventBus.java:247) ~[eventbus-5.0.3.jar%232!/:?]
# 	at net.minecraftforge.eventbus.EventBus.lambda$addListener$11(EventBus.java:239) ~[eventbus-5.0.3.jar%232!/:?]
# 	at net.minecraftforge.eventbus.EventBus.post(EventBus.java:302) ~[eventbus-5.0.3.jar%232!/:?]
# 	at net.minecraftforge.eventbus.EventBus.post(EventBus.java:283) ~[eventbus-5.0.3.jar%232!/:?]
# 	at net.minecraftforge.event.ForgeEventFactory.onPlayerPreTick(ForgeEventFactory.java:895) ~[forge-1.18.2-40.2.17-universal.jar%23303!/:?]
# 	at net.minecraft.world.entity.player.Player.m_8119_(Player.java:230) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.level.ServerPlayer.m_9240_(ServerPlayer.java:576) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	... 10 more
# [04:09:30 FATAL]: Preparing crash report with UUID 5d7ce1b0-9069-488e-84b7-88d2051d513a
# [04:09:30 ERROR]: This crash report has been saved to: /workspaces/codespaces-jupyter/Minecraft-server/./crash-reports/crash-2024-02-29_04.09.30-server.txt
# [04:09:30 INFO]: Stopping server
# [04:09:30 INFO]: Saving players
# [04:09:30 INFO]: Darkohh10 lost connection: Server closed
# [04:09:30 ERROR]: Exception caught during firing event: Cannot invoke "bottomtextdanny.dannys_expansion._base.capabilities.player.PlayerCapability.gunModule()" because the return value of "net.minecraftforge.common.util.LazyOptional.orElse(Object)" is null
# 	Index: 31
# 	Listeners:
# 		0: HIGH
# 		1: ASM: class dev.architectury.event.forge.EventHandlerImplCommon event(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		2: NORMAL
# 		3: ASM: class com.feywild.quest_giver.EventListener playerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		4: ASM: class tictim.paraglider.event.ParagliderEventHandler onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		5: net.minecraftforge.eventbus.EventBus$$Lambda/0x00007ff7f47f7098@1d91a0a3
# 		6: ASM: com.bobmowzie.mowziesmobs.server.ServerEventHandler@50b29518 onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		7: net.minecraftforge.eventbus.EventBus$$Lambda/0x00007ff7f47f7098@2584fbdc
# 		8: ASM: class com.mlib.contexts.OnPlayerTick onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		9: ASM: class net.mcreator.jet_and_elias_armors.procedures.SamuraiFullSetBonusProcedure onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		10: ASM: class net.mcreator.jet_and_elias_armors.procedures.HeavyIronArmorEffectsProcedure onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		11: ASM: class net.mcreator.jet_and_elias_armors.procedures.HavocKnightArmorBodyTickEventProcedure onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		12: ASM: class net.mcreator.jet_and_elias_armors.procedures.GladiatorArmorFullSetPassiveProcedure onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		13: ASM: class net.mcreator.jet_and_elias_armors.procedures.EliteSamuraiArmorFullSetPassiveProcedure onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		14: ASM: class net.mcreator.jet_and_elias_armors.procedures.EliteSamuraiArmorBlueFullSetPassiveProcedure onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		15: ASM: class net.mcreator.jet_and_elias_armors.procedures.CooldownARProcedure onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		16: ASM: class net.mcreator.jet_and_elias_armors.procedures.BulwarkFullSetPassiveProcedure onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		17: ASM: class net.mcreator.jet_and_elias_armors.procedures.BlueSamuraiFullSetBonusProcedure onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		18: ASM: class net.mcreator.jet_and_elias_armors.procedures.BIGHavocKnightFullSetBonusProcedure onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		19: net.minecraftforge.eventbus.EventBus$$Lambda/0x00007ff7f47f7098@6a1045b
# 		20: ASM: insane96mcp.progressivebosses.module.elderguardian.feature.BaseFeature@38d61d1 onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		21: ASM: class dev.ftb.mods.ftbessentials.FTBEEventHandler playerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		22: ASM: class com.hollingsworth.arsnouveau.common.potions.GravityEffect entityTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		23: ASM: class com.hollingsworth.arsnouveau.common.items.curios.CuriosEventHandler playerOnTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		24: ASM: class com.hollingsworth.arsnouveau.common.event.ManaCapEvents playerOnTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		25: ASM: class com.hollingsworth.arsnouveau.common.event.ManaCapEvents onTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		26: ASM: class com.hollingsworth.arsnouveau.common.event.LightEvents onTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		27: net.minecraftforge.eventbus.EventBus$$Lambda/0x00007ff7f47f7098@55644a6f
# 		28: ASM: class net.mcreator.enlightened_end.procedures.RadiumDustItemInHandTickProcedure onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		29: ASM: class net.mcreator.enlightened_end.procedures.RadiationTickProcedure onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		30: ASM: class com.minecraftserverzone.weaponmaster.setup.ForgeSetup changeCapabilityOfPlayersWhenHotbarChanges(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		31: net.minecraftforge.eventbus.EventBus$$Lambda/0x00007ff7f47f7098@45607cd8
# 		32: ASM: class net.mehvahdjukaar.supplementaries.common.events.ServerEvents onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		33: ASM: com.afunproject.dawncraft.EventListener@7df7cb8d playerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		34: ASM: class com.simibubi.create.content.equipment.bell.HauntedBellPulser hauntedBellCreatesPulse(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		35: ASM: vazkii.quark.content.tweaks.module.GrabChickensModule@3647bbae playerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		36: ASM: vazkii.quark.content.tweaks.module.EnhancedLaddersModule@205ce988 onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		37: ASM: vazkii.quark.content.tweaks.module.CompassesWorkEverywhereModule@2abccff5 onUpdate(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		38: ASM: vazkii.quark.content.tweaks.module.CampfiresBoostElytraModule@3f521e75 onPlayerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		39: ASM: me.lucko.spark.forge.ForgeTickHook@2eb16714 onTick(Lnet/minecraftforge/event/TickEvent;)V
# 		40: ASM: me.lucko.spark.forge.ForgeTickReporter@702b5893 onTick(Lnet/minecraftforge/event/TickEvent;)V
# 		41: net.minecraftforge.eventbus.EventBus$$Lambda/0x00007ff7f47f7098@47b835b3
# 		42: LOWEST
# 		43: ASM: class harmonised.pmmo.events.EventHandler playerTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		44: ASM: insane96mcp.insanelib.module.base.feature.FixFeature@5ad092f0 onUpdate(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# 		45: ASM: class com.hollingsworth.arsnouveau.common.event.EventHandler onGlideTick(Lnet/minecraftforge/event/TickEvent$PlayerTickEvent;)V
# java.lang.NullPointerException: Cannot invoke "bottomtextdanny.dannys_expansion._base.capabilities.player.PlayerCapability.gunModule()" because the return value of "net.minecraftforge.common.util.LazyOptional.orElse(Object)" is null
# 	at TRANSFORMER/dannys_expansion@1.2.6/bottomtextdanny.dannys_expansion._base.capabilities.player.PlayerHelper.gunModule(PlayerHelper.java:17)
# 	at TRANSFORMER/dannys_expansion@1.2.6/bottomtextdanny.dannys_expansion._base.gameplay_hooks.TickHooks.playerTickHook(TickHooks.java:22)
# 	at MC-BOOTSTRAP/eventbus@5.0.3/net.minecraftforge.eventbus.EventBus.doCastFilter(EventBus.java:247)
# 	at MC-BOOTSTRAP/eventbus@5.0.3/net.minecraftforge.eventbus.EventBus.lambda$addListener$11(EventBus.java:239)
# 	at MC-BOOTSTRAP/eventbus@5.0.3/net.minecraftforge.eventbus.EventBus.post(EventBus.java:302)
# 	at MC-BOOTSTRAP/eventbus@5.0.3/net.minecraftforge.eventbus.EventBus.post(EventBus.java:283)
# 	at TRANSFORMER/forge@40.2.17/net.minecraftforge.event.ForgeEventFactory.onPlayerPreTick(ForgeEventFactory.java:895)
# 	at TRANSFORMER/minecraft@1.18.2/net.minecraft.world.entity.player.Player.m_8119_(Player.java:230)
# 	at TRANSFORMER/minecraft@1.18.2/net.minecraft.server.level.ServerPlayer.m_9240_(ServerPlayer.java:576)
# 	at TRANSFORMER/minecraft@1.18.2/net.minecraft.server.players.PlayerList.m_11286_(PlayerList.java:437)
# 	at TRANSFORMER/minecraft@1.18.2/net.minecraft.server.network.ServerGamePacketListenerImpl.m_7026_(ServerGamePacketListenerImpl.java:1561)
# 	at TRANSFORMER/minecraft@1.18.2/net.minecraft.server.network.ServerGamePacketListenerImpl.disconnect(ServerGamePacketListenerImpl.java:411)
# 	at TRANSFORMER/minecraft@1.18.2/net.minecraft.server.players.PlayerList.m_11313_(PlayerList.java:998)
# 	at TRANSFORMER/minecraft@1.18.2/net.minecraft.server.MinecraftServer.m_7041_(MinecraftServer.java:750)
# 	at TRANSFORMER/minecraft@1.18.2/net.minecraft.server.dedicated.DedicatedServer.m_7041_(DedicatedServer.java:639)
# 	at TRANSFORMER/minecraft@1.18.2/net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:912)
# 	at TRANSFORMER/minecraft@1.18.2/net.minecraft.server.MinecraftServer.m_177918_(MinecraftServer.java:287)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
#
# [04:09:30 ERROR]: Exception stopping the server
# net.minecraft.ReportedException: Ticking player
# 	at net.minecraft.server.level.ServerPlayer.m_9240_(ServerPlayer.java:660) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.players.PlayerList.m_11286_(PlayerList.java:437) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.m_7026_(ServerGamePacketListenerImpl.java:1561) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.disconnect(ServerGamePacketListenerImpl.java:411) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.players.PlayerList.m_11313_(PlayerList.java:998) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.MinecraftServer.m_7041_(MinecraftServer.java:750) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.dedicated.DedicatedServer.m_7041_(DedicatedServer.java:639) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:912) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.MinecraftServer.m_177918_(MinecraftServer.java:287) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# Caused by: java.lang.NullPointerException: Cannot invoke "bottomtextdanny.dannys_expansion._base.capabilities.player.PlayerCapability.gunModule()" because the return value of "net.minecraftforge.common.util.LazyOptional.orElse(Object)" is null
# 	at bottomtextdanny.dannys_expansion._base.capabilities.player.PlayerHelper.gunModule(PlayerHelper.java:17) ~[dannys_expansion-1.2.6.jar%23122!/:1.2.6]
# 	at bottomtextdanny.dannys_expansion._base.gameplay_hooks.TickHooks.playerTickHook(TickHooks.java:22) ~[dannys_expansion-1.2.6.jar%23122!/:1.2.6]
# 	at net.minecraftforge.eventbus.EventBus.doCastFilter(EventBus.java:247) ~[eventbus-5.0.3.jar%232!/:?]
# 	at net.minecraftforge.eventbus.EventBus.lambda$addListener$11(EventBus.java:239) ~[eventbus-5.0.3.jar%232!/:?]
# 	at net.minecraftforge.eventbus.EventBus.post(EventBus.java:302) ~[eventbus-5.0.3.jar%232!/:?]
# 	at net.minecraftforge.eventbus.EventBus.post(EventBus.java:283) ~[eventbus-5.0.3.jar%232!/:?]
# 	at net.minecraftforge.event.ForgeEventFactory.onPlayerPreTick(ForgeEventFactory.java:895) ~[forge-1.18.2-40.2.17-universal.jar%23303!/:?]
# 	at net.minecraft.world.entity.player.Player.m_8119_(Player.java:230) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	at net.minecraft.server.level.ServerPlayer.m_9240_(ServerPlayer.java:576) ~[server-1.18.2-20220404.173914-srg.jar%23298!/:?]
# 	... 9 more
# >
# t=2024-02-29T04:09:30+0000 lvl=warn msg="failed to open private leg" id=ffecc7da9dba typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-02-29T04:09:31+0000 lvl=warn msg="failed to open private leg" id=56af73b8c1b4 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-02-29T04:09:31+0000 lvl=warn msg="failed to open private leg" id=e0c7ade602ae typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-02-29T04:09:32+0000 lvl=warn msg="failed to open private leg" id=0685dff768e6 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-02-29T04:09:34+0000 lvl=warn msg="failed to open private leg" id=96fce043a9e7 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-02-29T04:09:34+0000 lvl=warn msg="failed to open private leg" id=45b8f92cb7eb typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-02-29T04:09:34+0000 lvl=warn msg="failed to open private leg" id=cc558333313e typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-02-29T04:09:35+0000 lvl=warn msg="failed to open private leg" id=cc72e4a751ac typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-02-29T04:09:35+0000 lvl=warn msg="failed to open private leg" id=07c6f0e60ad8 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-02-29T04:09:35+0000 lvl=warn msg="failed to open private leg" id=6f3c2ffa62ad typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-02-29T04:09:37+0000 lvl=warn msg="failed to open private leg" id=2c37880a24e5 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-02-29T04:09:37+0000 lvl=warn msg="failed to open private leg" id=05d0c3c8dd32 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
